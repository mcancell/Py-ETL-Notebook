# %% [markdown]
# # Get the Emails from Pickled DF

# %%
import yaml
import pickle

# Open the pickle file and load the DataFrame
with open('../.pickles/df_emails_imap.pkl', 'rb') as f:
    df_emails_imap = pickle.load(f)

# %%
from IPython.display import display

display(df_emails_imap)

# %% [markdown]
# ## Convert the Email Date to a Valid Timestamp

# %%
import pandas as pd
# Convert 'Date' column to datetime format
df_emails_imap['Timestamp'] = pd.to_datetime(df_emails_imap['Date'])

# Drop the old 'Date' column
df_emails_imap.drop(columns=['Date'], inplace=True)

# Display the updated DataFrame
display(df_emails_imap)
# Out:
#                                                 Subject  \
# 0                      See what's streaming in December
# 1     Coming soon to State Theatre New Jersey: Cirqu...
# 2                  =?utf-8?q?Will_Obama_go_to_jail=3F?=
# 3      Your Daily Digest for Sun, 12/1 is ready to view
# 4     Your Weekly Ad + Holiday Savings to Deck the H...
# ...                                                 ...
# 1031              New Year, New Opportunities with NDR!
# 1032                       More opportunities available
# 1033     Thank you for your interest in Quince, Michael
# 1034                    Update on your Alma Application
# 1035                         Thanks for applying to ECP
#
#                                                    From  \
# 0                    "IMDb.com" <do-not-reply@imdb.com>
# 1     Bandsintown <notifications@updates.bandsintown...
# 2     Quora Digest <english-personalized-digest@quor...
# 3     USPS Informed Delivery <USPSInformeddelivery@e...
# 4     =?UTF-8?B?Q1ZTIEV4dHJhQ2FyZQ==?= <extracare@yo...
# ...                                                 ...
# 1031  "National Debt Relief LLC Careers" <nationalde...
# 1032               HustleWing <hello@thehustlewing.com>
# 1033                             no-reply@onequince.com
# 1034                             no-reply@helloalma.com
# 1035     Workable <noreply@candidates.workablemail.com>
#
#                                            To  \
# 0                      mike.cancell@gmail.com
# 1                      mike.cancell@gmail.com
# 2                      mike.cancell@gmail.com
# 3                      mike.cancell@gmail.com
# 4                        mike@mikecancell.com
# ...                                       ...
# 1031  "Mike Cancell" <mike.cancell@gmail.com>
# 1032                   mike.cancell@gmail.com
# 1033                   mike.cancell@gmail.com
# 1034                   mike.cancell@gmail.com
# 1035                   mike.cancell@gmail.com
#
#                                              Message-ID  \
# 0     <01000193814d60c2-fd528199-2ca9-40dc-8c71-c310...
# 1               <msg-19742805299@email.bandsintown.com>
# 2     <LARkCC7mJXguO-fXuuzZcwMdZJYRZCZHc2nstcrUwcMNj...
# 3     <20241201122732.9884238d69c03837@email.informe...
# 4        <0.3.9.54A.1DB43F26A5DD630.0@omp.your.cvs.com>
# ...                                                 ...
# 1031  <44.B0.11346.7C572976@i-0781014fc37ad6864.mta1...
# 1032  <010001949420d725-a7c812c3-e1be-4b04-8651-bcd6...
# 1033  <20250123171257.e66f35b6b0e4ab8d@gh-mail.onequ...
# 1034  <20250123173904.2f49b196001b2525@gh-mail.hello...
# 1035  <df0066ff-af68-4061-b474-f0610f4d1716@workable...
#
#                                                    Body  \
# 0     IMDb Streaming Guides\r\nCheck out our watch g...
# 1     Just Announced Cirque Musica, New Jersey Symph...
# 2     Top stories for Mike\r\n\r\n-----\r\n\r\nQuest...
# 3     Content-Type: text/plain; charset=UTF-8\r\nCon...
# 4     <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...
# ...                                                 ...
# 1031  ![image] (https://tracking.icims.com/f/a/Fdz8p...
# 1032  \r\nHey Michael,\r\nI saw that you applied to ...
# 1033  Hi Michael,\r\n\r\nThank you for your interest...
# 1034  Hi Michael,\r\n\r\nThank you very much for tak...
# 1035  ECP\r\n\r\n-----------------------------------...
#
#                                                Reply-To  \
# 0                    "IMDb.com" <do-not-reply@imdb.com>
# 1     Bandsintown <notifications@updates.bandsintown...
# 2     Quora Digest <english-personalized-digest@quor...
# 3     USPS Informed Delivery <USPSInformeddelivery@e...
# 4     =?UTF-8?B?Q1ZTIEV4dHJhQ2FyZQ==?= <noreply@your...
# ...                                                 ...
# 1031       no-reply@nationaldebtrelief.talent.icims.com
# 1032               HustleWing <hello@thehustlewing.com>
# 1033                             no-reply@onequince.com
# 1034                             no-reply@helloalma.com
# 1035     Workable <noreply@candidates.workablemail.com>
#
#                      Timestamp
# 0    2024-12-01 08:19:12+00:00
# 1    2024-12-01 08:51:40+00:00
# 2    2024-12-01 12:03:31+00:00
# 3    2024-12-01 12:27:32+00:00
# 4    2024-12-01 13:10:38+00:00
# ...                        ...
# 1031 2025-01-23 17:00:55+00:00
# 1032 2025-01-23 17:06:07+00:00
# 1033 2025-01-23 17:12:57+00:00
# 1034 2025-01-23 17:39:04+00:00
# 1035 2025-01-23 17:58:25+00:00
#
# [1036 rows x 7 columns]

# %% [markdown]
# ## From the From and To Cols, Extract the Actual Addr and the Display Name in Sep Cols

# %%
import re

# Function to extract email address and display name
def extract_email_and_name(email):
    match = re.match(r'(?:"?([^"]*)"?\s)?(?:<?(.+@[^>]+)>?)', email)
    if match:
        display_name, email_address = match.groups()
        if not display_name:
            display_name = email_address.split('@')[0]
        return display_name, email_address
    return email, email

# Apply the function to the 'From' column
df_emails_imap[['From_Display_Name', 'From_Addr']] = df_emails_imap['From'].apply(lambda x: pd.Series(extract_email_and_name(x)))

# Apply the function to the 'To' column
df_emails_imap[['To_Display_Name', 'To_Addr']] = df_emails_imap['To'].apply(lambda x: pd.Series(extract_email_and_name(x)))

# Apply the function to the 'Reply-To' column
df_emails_imap[['Reply-To_Display_Name', 'Reply-To_Addr']] = df_emails_imap['Reply-To'].apply(lambda x: pd.Series(extract_email_and_name(x)))
#
display(df_emails_imap[['Timestamp', 'Subject', 'From_Display_Name', 'From_Addr', 'To_Display_Name', 'To_Addr', 'Message-ID', 'Body', 'Reply-To']])
# Out:
#                      Timestamp  \
# 0    2024-12-01 08:19:12+00:00
# 1    2024-12-01 08:51:40+00:00
# 2    2024-12-01 12:03:31+00:00
# 3    2024-12-01 12:27:32+00:00
# 4    2024-12-01 13:10:38+00:00
# ...                        ...
# 1031 2025-01-23 17:00:55+00:00
# 1032 2025-01-23 17:06:07+00:00
# 1033 2025-01-23 17:12:57+00:00
# 1034 2025-01-23 17:39:04+00:00
# 1035 2025-01-23 17:58:25+00:00
#
#                                                 Subject  \
# 0                      See what's streaming in December
# 1     Coming soon to State Theatre New Jersey: Cirqu...
# 2                  =?utf-8?q?Will_Obama_go_to_jail=3F?=
# 3      Your Daily Digest for Sun, 12/1 is ready to view
# 4     Your Weekly Ad + Holiday Savings to Deck the H...
# ...                                                 ...
# 1031              New Year, New Opportunities with NDR!
# 1032                       More opportunities available
# 1033     Thank you for your interest in Quince, Michael
# 1034                    Update on your Alma Application
# 1035                         Thanks for applying to ECP
#
#                      From_Display_Name  \
# 0                             IMDb.com
# 1                          Bandsintown
# 2                         Quora Digest
# 3               USPS Informed Delivery
# 4     =?UTF-8?B?Q1ZTIEV4dHJhQ2FyZQ==?=
# ...                                ...
# 1031  National Debt Relief LLC Careers
# 1032                        HustleWing
# 1033                          no-reply
# 1034                          no-reply
# 1035                          Workable
#
#                                               From_Addr To_Display_Name  \
# 0                                 do-not-reply@imdb.com    mike.cancell
# 1                 notifications@updates.bandsintown.com    mike.cancell
# 2                 english-personalized-digest@quora.com    mike.cancell
# 3     USPSInformeddelivery@email.informeddelivery.us...    mike.cancell
# 4                                extracare@your.cvs.com            mike
# ...                                                 ...             ...
# 1031               nationaldebtrelief@nurture.icims.com    Mike Cancell
# 1032                            hello@thehustlewing.com    mike.cancell
# 1033                             no-reply@onequince.com    mike.cancell
# 1034                             no-reply@helloalma.com    mike.cancell
# 1035                noreply@candidates.workablemail.com    mike.cancell
#
#                      To_Addr  \
# 0     mike.cancell@gmail.com
# 1     mike.cancell@gmail.com
# 2     mike.cancell@gmail.com
# 3     mike.cancell@gmail.com
# 4       mike@mikecancell.com
# ...                      ...
# 1031  mike.cancell@gmail.com
# 1032  mike.cancell@gmail.com
# 1033  mike.cancell@gmail.com
# 1034  mike.cancell@gmail.com
# 1035  mike.cancell@gmail.com
#
#                                              Message-ID  \
# 0     <01000193814d60c2-fd528199-2ca9-40dc-8c71-c310...
# 1               <msg-19742805299@email.bandsintown.com>
# 2     <LARkCC7mJXguO-fXuuzZcwMdZJYRZCZHc2nstcrUwcMNj...
# 3     <20241201122732.9884238d69c03837@email.informe...
# 4        <0.3.9.54A.1DB43F26A5DD630.0@omp.your.cvs.com>
# ...                                                 ...
# 1031  <44.B0.11346.7C572976@i-0781014fc37ad6864.mta1...
# 1032  <010001949420d725-a7c812c3-e1be-4b04-8651-bcd6...
# 1033  <20250123171257.e66f35b6b0e4ab8d@gh-mail.onequ...
# 1034  <20250123173904.2f49b196001b2525@gh-mail.hello...
# 1035  <df0066ff-af68-4061-b474-f0610f4d1716@workable...
#
#                                                    Body  \
# 0     IMDb Streaming Guides\r\nCheck out our watch g...
# 1     Just Announced Cirque Musica, New Jersey Symph...
# 2     Top stories for Mike\r\n\r\n-----\r\n\r\nQuest...
# 3     Content-Type: text/plain; charset=UTF-8\r\nCon...
# 4     <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...
# ...                                                 ...
# 1031  ![image] (https://tracking.icims.com/f/a/Fdz8p...
# 1032  \r\nHey Michael,\r\nI saw that you applied to ...
# 1033  Hi Michael,\r\n\r\nThank you for your interest...
# 1034  Hi Michael,\r\n\r\nThank you very much for tak...
# 1035  ECP\r\n\r\n-----------------------------------...
#
#                                                Reply-To
# 0                    "IMDb.com" <do-not-reply@imdb.com>
# 1     Bandsintown <notifications@updates.bandsintown...
# 2     Quora Digest <english-personalized-digest@quor...
# 3     USPS Informed Delivery <USPSInformeddelivery@e...
# 4     =?UTF-8?B?Q1ZTIEV4dHJhQ2FyZQ==?= <noreply@your...
# ...                                                 ...
# 1031       no-reply@nationaldebtrelief.talent.icims.com
# 1032               HustleWing <hello@thehustlewing.com>
# 1033                             no-reply@onequince.com
# 1034                             no-reply@helloalma.com
# 1035     Workable <noreply@candidates.workablemail.com>
#
# [1036 rows x 9 columns]

# %% [markdown]
# ## Quick Check for Missing Data

# %%
missing_data = df_emails_imap.isnull().sum()
print(missing_data)
# Out:
# Subject                  0
# From                     0
# To                       0
# Message-ID               0
# Body                     0
# Reply-To                 0
# Timestamp                0
# From_Display_Name        0
# From_Addr                0
# To_Display_Name          0
# To_Addr                  0
# Reply-To_Display_Name    0
# Reply-To_Addr            0
# dtype: int64

# %% [markdown]
# ## Clean up the Body to remove HTML & CSS Markup

# %%
from bs4 import BeautifulSoup
import re

# Function to remove HTML markup, CSS style tags, and URLs
def remove_markup_and_urls(text):
    soup = BeautifulSoup(text, 'html.parser')
    # Remove CSS style tags
    for style in soup(["style"]):
        style.decompose()
    text_without_markup = soup.get_text()
    text_without_urls = re.sub(r'http\S+|www\S+|https\S+', '', text_without_markup, flags=re.MULTILINE)
    # Remove any remaining CSS markup
    text_without_css = re.sub(r'{.*?}', '', text_without_urls, flags=re.DOTALL)
    # Remove any remaining HTML tags
    clean_text = re.sub(r'<.*?>', '', text_without_css)
    return clean_text.strip()

# Apply the function to the 'Body' column
df_emails_imap['Body_Text'] = df_emails_imap['Body'].apply(remove_markup_and_urls)

# Display the updated DataFrame
display(df_emails_imap)
# Out:
# C:\Users\mike\AppData\Local\Temp\ipykernel_34248\3308429135.py:6: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   soup = BeautifulSoup(text, 'html.parser')
# C:\Users\mike\AppData\Local\Temp\ipykernel_34248\3308429135.py:6: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(text, 'html.parser')
#                                                 Subject  \
# 0                      See what's streaming in December
# 1     Coming soon to State Theatre New Jersey: Cirqu...
# 2                  =?utf-8?q?Will_Obama_go_to_jail=3F?=
# 3      Your Daily Digest for Sun, 12/1 is ready to view
# 4     Your Weekly Ad + Holiday Savings to Deck the H...
# ...                                                 ...
# 1031              New Year, New Opportunities with NDR!
# 1032                       More opportunities available
# 1033     Thank you for your interest in Quince, Michael
# 1034                    Update on your Alma Application
# 1035                         Thanks for applying to ECP
#
#                                                    From  \
# 0                    "IMDb.com" <do-not-reply@imdb.com>
# 1     Bandsintown <notifications@updates.bandsintown...
# 2     Quora Digest <english-personalized-digest@quor...
# 3     USPS Informed Delivery <USPSInformeddelivery@e...
# 4     =?UTF-8?B?Q1ZTIEV4dHJhQ2FyZQ==?= <extracare@yo...
# ...                                                 ...
# 1031  "National Debt Relief LLC Careers" <nationalde...
# 1032               HustleWing <hello@thehustlewing.com>
# 1033                             no-reply@onequince.com
# 1034                             no-reply@helloalma.com
# 1035     Workable <noreply@candidates.workablemail.com>
#
#                                            To  \
# 0                      mike.cancell@gmail.com
# 1                      mike.cancell@gmail.com
# 2                      mike.cancell@gmail.com
# 3                      mike.cancell@gmail.com
# 4                        mike@mikecancell.com
# ...                                       ...
# 1031  "Mike Cancell" <mike.cancell@gmail.com>
# 1032                   mike.cancell@gmail.com
# 1033                   mike.cancell@gmail.com
# 1034                   mike.cancell@gmail.com
# 1035                   mike.cancell@gmail.com
#
#                                              Message-ID  \
# 0     <01000193814d60c2-fd528199-2ca9-40dc-8c71-c310...
# 1               <msg-19742805299@email.bandsintown.com>
# 2     <LARkCC7mJXguO-fXuuzZcwMdZJYRZCZHc2nstcrUwcMNj...
# 3     <20241201122732.9884238d69c03837@email.informe...
# 4        <0.3.9.54A.1DB43F26A5DD630.0@omp.your.cvs.com>
# ...                                                 ...
# 1031  <44.B0.11346.7C572976@i-0781014fc37ad6864.mta1...
# 1032  <010001949420d725-a7c812c3-e1be-4b04-8651-bcd6...
# 1033  <20250123171257.e66f35b6b0e4ab8d@gh-mail.onequ...
# 1034  <20250123173904.2f49b196001b2525@gh-mail.hello...
# 1035  <df0066ff-af68-4061-b474-f0610f4d1716@workable...
#
#                                                    Body  \
# 0     IMDb Streaming Guides\r\nCheck out our watch g...
# 1     Just Announced Cirque Musica, New Jersey Symph...
# 2     Top stories for Mike\r\n\r\n-----\r\n\r\nQuest...
# 3     Content-Type: text/plain; charset=UTF-8\r\nCon...
# 4     <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...
# ...                                                 ...
# 1031  ![image] (https://tracking.icims.com/f/a/Fdz8p...
# 1032  \r\nHey Michael,\r\nI saw that you applied to ...
# 1033  Hi Michael,\r\n\r\nThank you for your interest...
# 1034  Hi Michael,\r\n\r\nThank you very much for tak...
# 1035  ECP\r\n\r\n-----------------------------------...
#
#                                                Reply-To  \
# 0                    "IMDb.com" <do-not-reply@imdb.com>
# 1     Bandsintown <notifications@updates.bandsintown...
# 2     Quora Digest <english-personalized-digest@quor...
# 3     USPS Informed Delivery <USPSInformeddelivery@e...
# 4     =?UTF-8?B?Q1ZTIEV4dHJhQ2FyZQ==?= <noreply@your...
# ...                                                 ...
# 1031       no-reply@nationaldebtrelief.talent.icims.com
# 1032               HustleWing <hello@thehustlewing.com>
# 1033                             no-reply@onequince.com
# 1034                             no-reply@helloalma.com
# 1035     Workable <noreply@candidates.workablemail.com>
#
#                      Timestamp                 From_Display_Name  \
# 0    2024-12-01 08:19:12+00:00                          IMDb.com
# 1    2024-12-01 08:51:40+00:00                       Bandsintown
# 2    2024-12-01 12:03:31+00:00                      Quora Digest
# 3    2024-12-01 12:27:32+00:00            USPS Informed Delivery
# 4    2024-12-01 13:10:38+00:00  =?UTF-8?B?Q1ZTIEV4dHJhQ2FyZQ==?=
# ...                        ...                               ...
# 1031 2025-01-23 17:00:55+00:00  National Debt Relief LLC Careers
# 1032 2025-01-23 17:06:07+00:00                        HustleWing
# 1033 2025-01-23 17:12:57+00:00                          no-reply
# 1034 2025-01-23 17:39:04+00:00                          no-reply
# 1035 2025-01-23 17:58:25+00:00                          Workable
#
#                                               From_Addr To_Display_Name  \
# 0                                 do-not-reply@imdb.com    mike.cancell
# 1                 notifications@updates.bandsintown.com    mike.cancell
# 2                 english-personalized-digest@quora.com    mike.cancell
# 3     USPSInformeddelivery@email.informeddelivery.us...    mike.cancell
# 4                                extracare@your.cvs.com            mike
# ...                                                 ...             ...
# 1031               nationaldebtrelief@nurture.icims.com    Mike Cancell
# 1032                            hello@thehustlewing.com    mike.cancell
# 1033                             no-reply@onequince.com    mike.cancell
# 1034                             no-reply@helloalma.com    mike.cancell
# 1035                noreply@candidates.workablemail.com    mike.cancell
#
#                      To_Addr             Reply-To_Display_Name  \
# 0     mike.cancell@gmail.com                          IMDb.com
# 1     mike.cancell@gmail.com                       Bandsintown
# 2     mike.cancell@gmail.com                      Quora Digest
# 3     mike.cancell@gmail.com            USPS Informed Delivery
# 4       mike@mikecancell.com  =?UTF-8?B?Q1ZTIEV4dHJhQ2FyZQ==?=
# ...                      ...                               ...
# 1031  mike.cancell@gmail.com                          no-reply
# 1032  mike.cancell@gmail.com                        HustleWing
# 1033  mike.cancell@gmail.com                          no-reply
# 1034  mike.cancell@gmail.com                          no-reply
# 1035  mike.cancell@gmail.com                          Workable
#
#                                           Reply-To_Addr  \
# 0                                 do-not-reply@imdb.com
# 1                 notifications@updates.bandsintown.com
# 2                 english-personalized-digest@quora.com
# 3     USPSInformeddelivery@email.informeddelivery.us...
# 4                                  noreply@your.cvs.com
# ...                                                 ...
# 1031       no-reply@nationaldebtrelief.talent.icims.com
# 1032                            hello@thehustlewing.com
# 1033                             no-reply@onequince.com
# 1034                             no-reply@helloalma.com
# 1035                noreply@candidates.workablemail.com
#
#                                               Body_Text
# 0     IMDb Streaming Guides\r\nCheck out our watch g...
# 1     Just Announced Cirque Musica, New Jersey Symph...
# 2     Top stories for Mike\r\n\r\n-----\r\n\r\nQuest...
# 3     Content-Type: text/plain; charset=UTF-8\r\nCon...
# 4     CVS\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# ...                                                 ...
# 1031  ![image] (\r\n \r\nCheck out our open roles an...
# 1032  Hey Michael,\r\nI saw that you applied to an o...
# 1033  Hi Michael,\r\n\r\nThank you for your interest...
# 1034  Hi Michael,\r\n\r\nThank you very much for tak...
# 1035  ECP\r\n\r\n-----------------------------------...
#
# [1036 rows x 14 columns]

# %%
print(df_emails_imap.dtypes)
# Out:
# Subject                               object
# From                                  object
# To                                    object
# Message-ID                            object
# Body                                  object
# Reply-To                              object
# Timestamp                datetime64[ns, UTC]
# From_Display_Name                     object
# From_Addr                             object
# To_Display_Name                       object
# To_Addr                               object
# Reply-To_Display_Name                 object
# Reply-To_Addr                         object
# Body_Text                             object
# dtype: object

# %% [markdown]
# ## Drop the Original From/To Cols (post split)

# %%
# Drop the specified columns
df_emails_imap.drop(columns=['From', 'To', 'Body', 'Reply-To'], inplace=True)

# Display the remaining columns
display(df_emails_imap)
# Out:
#                                                 Subject  \
# 0                      See what's streaming in December
# 1     Coming soon to State Theatre New Jersey: Cirqu...
# 2                  =?utf-8?q?Will_Obama_go_to_jail=3F?=
# 3      Your Daily Digest for Sun, 12/1 is ready to view
# 4     Your Weekly Ad + Holiday Savings to Deck the H...
# ...                                                 ...
# 1031              New Year, New Opportunities with NDR!
# 1032                       More opportunities available
# 1033     Thank you for your interest in Quince, Michael
# 1034                    Update on your Alma Application
# 1035                         Thanks for applying to ECP
#
#                                              Message-ID  \
# 0     <01000193814d60c2-fd528199-2ca9-40dc-8c71-c310...
# 1               <msg-19742805299@email.bandsintown.com>
# 2     <LARkCC7mJXguO-fXuuzZcwMdZJYRZCZHc2nstcrUwcMNj...
# 3     <20241201122732.9884238d69c03837@email.informe...
# 4        <0.3.9.54A.1DB43F26A5DD630.0@omp.your.cvs.com>
# ...                                                 ...
# 1031  <44.B0.11346.7C572976@i-0781014fc37ad6864.mta1...
# 1032  <010001949420d725-a7c812c3-e1be-4b04-8651-bcd6...
# 1033  <20250123171257.e66f35b6b0e4ab8d@gh-mail.onequ...
# 1034  <20250123173904.2f49b196001b2525@gh-mail.hello...
# 1035  <df0066ff-af68-4061-b474-f0610f4d1716@workable...
#
#                      Timestamp                 From_Display_Name  \
# 0    2024-12-01 08:19:12+00:00                          IMDb.com
# 1    2024-12-01 08:51:40+00:00                       Bandsintown
# 2    2024-12-01 12:03:31+00:00                      Quora Digest
# 3    2024-12-01 12:27:32+00:00            USPS Informed Delivery
# 4    2024-12-01 13:10:38+00:00  =?UTF-8?B?Q1ZTIEV4dHJhQ2FyZQ==?=
# ...                        ...                               ...
# 1031 2025-01-23 17:00:55+00:00  National Debt Relief LLC Careers
# 1032 2025-01-23 17:06:07+00:00                        HustleWing
# 1033 2025-01-23 17:12:57+00:00                          no-reply
# 1034 2025-01-23 17:39:04+00:00                          no-reply
# 1035 2025-01-23 17:58:25+00:00                          Workable
#
#                                               From_Addr To_Display_Name  \
# 0                                 do-not-reply@imdb.com    mike.cancell
# 1                 notifications@updates.bandsintown.com    mike.cancell
# 2                 english-personalized-digest@quora.com    mike.cancell
# 3     USPSInformeddelivery@email.informeddelivery.us...    mike.cancell
# 4                                extracare@your.cvs.com            mike
# ...                                                 ...             ...
# 1031               nationaldebtrelief@nurture.icims.com    Mike Cancell
# 1032                            hello@thehustlewing.com    mike.cancell
# 1033                             no-reply@onequince.com    mike.cancell
# 1034                             no-reply@helloalma.com    mike.cancell
# 1035                noreply@candidates.workablemail.com    mike.cancell
#
#                      To_Addr             Reply-To_Display_Name  \
# 0     mike.cancell@gmail.com                          IMDb.com
# 1     mike.cancell@gmail.com                       Bandsintown
# 2     mike.cancell@gmail.com                      Quora Digest
# 3     mike.cancell@gmail.com            USPS Informed Delivery
# 4       mike@mikecancell.com  =?UTF-8?B?Q1ZTIEV4dHJhQ2FyZQ==?=
# ...                      ...                               ...
# 1031  mike.cancell@gmail.com                          no-reply
# 1032  mike.cancell@gmail.com                        HustleWing
# 1033  mike.cancell@gmail.com                          no-reply
# 1034  mike.cancell@gmail.com                          no-reply
# 1035  mike.cancell@gmail.com                          Workable
#
#                                           Reply-To_Addr  \
# 0                                 do-not-reply@imdb.com
# 1                 notifications@updates.bandsintown.com
# 2                 english-personalized-digest@quora.com
# 3     USPSInformeddelivery@email.informeddelivery.us...
# 4                                  noreply@your.cvs.com
# ...                                                 ...
# 1031       no-reply@nationaldebtrelief.talent.icims.com
# 1032                            hello@thehustlewing.com
# 1033                             no-reply@onequince.com
# 1034                             no-reply@helloalma.com
# 1035                noreply@candidates.workablemail.com
#
#                                               Body_Text
# 0     IMDb Streaming Guides\r\nCheck out our watch g...
# 1     Just Announced Cirque Musica, New Jersey Symph...
# 2     Top stories for Mike\r\n\r\n-----\r\n\r\nQuest...
# 3     Content-Type: text/plain; charset=UTF-8\r\nCon...
# 4     CVS\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# ...                                                 ...
# 1031  ![image] (\r\n \r\nCheck out our open roles an...
# 1032  Hey Michael,\r\nI saw that you applied to an o...
# 1033  Hi Michael,\r\n\r\nThank you for your interest...
# 1034  Hi Michael,\r\n\r\nThank you very much for tak...
# 1035  ECP\r\n\r\n-----------------------------------...
#
# [1036 rows x 10 columns]

# %% [markdown]
# ## Create a Category from the Body and From Addr

# %%
# Define a function to categorize the body text
def categorize_body_text(body_text):
    body_text_lower = body_text.lower()
    if 'rejection' in body_text_lower or 'not selected' in body_text_lower or 'unfortunately' in body_text_lower:
        return 'Job Rejection'
    elif 'application' in body_text_lower and 'received' in body_text_lower:
        return 'Job Application'
    elif 'invoice' in body_text_lower:
        return 'Invoice'
    elif 'promotion' in body_text_lower:
        return 'Promotion'
    elif 'newsletter' in body_text_lower:
        return 'Newsletter'
    elif 'reminder' in body_text_lower:
        return 'Reminder'
    elif 'meeting' in body_text_lower or 'schedule' in body_text_lower:
        return 'Meeting'
    elif 'password' in body_text_lower or 'reset' in body_text_lower:
        return 'Password Reset'
    elif 'shipping' in body_text_lower or 'delivery' in body_text_lower:
        return 'Shipping'
    elif 'receipt' in body_text_lower or 'purchase' in body_text_lower:
        return 'Receipt'
    else:
        return 'Other'

# Apply the function to the 'Body_Text' column
df_emails_imap['Category'] = df_emails_imap['Body_Text'].apply(categorize_body_text)

# Function to categorize by From_Addr
def categorize_from_addr(from_addr):
    if 'wellsfargo' in from_addr:
        return 'Bank'
    elif 'greenhouse' in from_addr or 'lever' in from_addr:
        return 'Job Application'
    elif 'usps' in from_addr:
        return 'Shipping'
    elif 'njmmail' in from_addr:
        return 'Insurance'
    elif 'imdb' in from_addr:
        return 'Entertainment'
    elif 'bandsintown' in from_addr:
        return 'Music'
    elif 'quora' in from_addr:
        return 'Newsletter'
    elif 'synchronyfinancial' in from_addr:
        return 'Finance'
    elif 'google' in from_addr:
        return 'Tech'
    elif 'dayforce' in from_addr or 'trimble' in from_addr or 'workday' in from_addr:
        return 'Job Application'
    elif 'chick-fil-a' in from_addr:
        return 'Food'
    else:
        return 'Other'

# Apply the function to the 'From_Addr' column
df_emails_imap['From_Addr_Category'] = df_emails_imap['From_Addr'].apply(categorize_from_addr)

# Combine the categories from Body_Text and From_Addr
def combine_categories(row):
    if row['Category'] != 'Other':
        return row['Category']
    else:
        return row['From_Addr_Category']

# Apply the function to combine categories
df_emails_imap['Email_Category'] = df_emails_imap.apply(combine_categories, axis=1)

# Drop the intermediate 'From_Addr_Category' column
df_emails_imap.drop(columns=['From_Addr_Category'], inplace=True)

# Display the updated DataFrame
display(df_emails_imap)
# Out:
#                                                 Subject  \
# 0                      See what's streaming in December
# 1     Coming soon to State Theatre New Jersey: Cirqu...
# 2                  =?utf-8?q?Will_Obama_go_to_jail=3F?=
# 3      Your Daily Digest for Sun, 12/1 is ready to view
# 4     Your Weekly Ad + Holiday Savings to Deck the H...
# ...                                                 ...
# 1031              New Year, New Opportunities with NDR!
# 1032                       More opportunities available
# 1033     Thank you for your interest in Quince, Michael
# 1034                    Update on your Alma Application
# 1035                         Thanks for applying to ECP
#
#                                              Message-ID  \
# 0     <01000193814d60c2-fd528199-2ca9-40dc-8c71-c310...
# 1               <msg-19742805299@email.bandsintown.com>
# 2     <LARkCC7mJXguO-fXuuzZcwMdZJYRZCZHc2nstcrUwcMNj...
# 3     <20241201122732.9884238d69c03837@email.informe...
# 4        <0.3.9.54A.1DB43F26A5DD630.0@omp.your.cvs.com>
# ...                                                 ...
# 1031  <44.B0.11346.7C572976@i-0781014fc37ad6864.mta1...
# 1032  <010001949420d725-a7c812c3-e1be-4b04-8651-bcd6...
# 1033  <20250123171257.e66f35b6b0e4ab8d@gh-mail.onequ...
# 1034  <20250123173904.2f49b196001b2525@gh-mail.hello...
# 1035  <df0066ff-af68-4061-b474-f0610f4d1716@workable...
#
#                      Timestamp                 From_Display_Name  \
# 0    2024-12-01 08:19:12+00:00                          IMDb.com
# 1    2024-12-01 08:51:40+00:00                       Bandsintown
# 2    2024-12-01 12:03:31+00:00                      Quora Digest
# 3    2024-12-01 12:27:32+00:00            USPS Informed Delivery
# 4    2024-12-01 13:10:38+00:00  =?UTF-8?B?Q1ZTIEV4dHJhQ2FyZQ==?=
# ...                        ...                               ...
# 1031 2025-01-23 17:00:55+00:00  National Debt Relief LLC Careers
# 1032 2025-01-23 17:06:07+00:00                        HustleWing
# 1033 2025-01-23 17:12:57+00:00                          no-reply
# 1034 2025-01-23 17:39:04+00:00                          no-reply
# 1035 2025-01-23 17:58:25+00:00                          Workable
#
#                                               From_Addr To_Display_Name  \
# 0                                 do-not-reply@imdb.com    mike.cancell
# 1                 notifications@updates.bandsintown.com    mike.cancell
# 2                 english-personalized-digest@quora.com    mike.cancell
# 3     USPSInformeddelivery@email.informeddelivery.us...    mike.cancell
# 4                                extracare@your.cvs.com            mike
# ...                                                 ...             ...
# 1031               nationaldebtrelief@nurture.icims.com    Mike Cancell
# 1032                            hello@thehustlewing.com    mike.cancell
# 1033                             no-reply@onequince.com    mike.cancell
# 1034                             no-reply@helloalma.com    mike.cancell
# 1035                noreply@candidates.workablemail.com    mike.cancell
#
#                      To_Addr             Reply-To_Display_Name  \
# 0     mike.cancell@gmail.com                          IMDb.com
# 1     mike.cancell@gmail.com                       Bandsintown
# 2     mike.cancell@gmail.com                      Quora Digest
# 3     mike.cancell@gmail.com            USPS Informed Delivery
# 4       mike@mikecancell.com  =?UTF-8?B?Q1ZTIEV4dHJhQ2FyZQ==?=
# ...                      ...                               ...
# 1031  mike.cancell@gmail.com                          no-reply
# 1032  mike.cancell@gmail.com                        HustleWing
# 1033  mike.cancell@gmail.com                          no-reply
# 1034  mike.cancell@gmail.com                          no-reply
# 1035  mike.cancell@gmail.com                          Workable
#
#                                           Reply-To_Addr  \
# 0                                 do-not-reply@imdb.com
# 1                 notifications@updates.bandsintown.com
# 2                 english-personalized-digest@quora.com
# 3     USPSInformeddelivery@email.informeddelivery.us...
# 4                                  noreply@your.cvs.com
# ...                                                 ...
# 1031       no-reply@nationaldebtrelief.talent.icims.com
# 1032                            hello@thehustlewing.com
# 1033                             no-reply@onequince.com
# 1034                             no-reply@helloalma.com
# 1035                noreply@candidates.workablemail.com
#
#                                               Body_Text       Category  \
# 0     IMDb Streaming Guides\r\nCheck out our watch g...          Other
# 1     Just Announced Cirque Musica, New Jersey Symph...          Other
# 2     Top stories for Mike\r\n\r\n-----\r\n\r\nQuest...          Other
# 3     Content-Type: text/plain; charset=UTF-8\r\nCon...       Shipping
# 4     CVS\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...       Shipping
# ...                                                 ...            ...
# 1031  ![image] (\r\n \r\nCheck out our open roles an...          Other
# 1032  Hey Michael,\r\nI saw that you applied to an o...          Other
# 1033  Hi Michael,\r\n\r\nThank you for your interest...  Job Rejection
# 1034  Hi Michael,\r\n\r\nThank you very much for tak...  Job Rejection
# 1035  ECP\r\n\r\n-----------------------------------...          Other
#
#      Email_Category
# 0     Entertainment
# 1             Music
# 2        Newsletter
# 3          Shipping
# 4          Shipping
# ...             ...
# 1031          Other
# 1032          Other
# 1033  Job Rejection
# 1034  Job Rejection
# 1035          Other
#
# [1036 rows x 12 columns]

# %% [markdown]
# # Design a Schema for the Data

# %% [markdown]
# ### Defined a Date_Time Dimension

# %%
# Create a datetime dimension DataFrame
df_datetime_dim = pd.DataFrame({
	'fk_Timestamp': df_emails_imap['Timestamp'].unique()
})

# Add additional columns
df_datetime_dim['Date'] = df_datetime_dim['fk_Timestamp'].dt.date
df_datetime_dim['Time'] = df_datetime_dim['fk_Timestamp'].dt.time
df_datetime_dim['Hour'] = df_datetime_dim['fk_Timestamp'].dt.hour
df_datetime_dim['Day_of_Week'] = df_datetime_dim['fk_Timestamp'].dt.dayofweek
df_datetime_dim['Day_of_Week_String'] = df_datetime_dim['fk_Timestamp'].dt.strftime('%a')

# Arrange 'fk_Timestamp' as the first column
cols = ['fk_Timestamp'] + [col for col in df_datetime_dim.columns if col != 'fk_Timestamp']
df_datetime_dim = df_datetime_dim[cols]

# Display the updated DataFrame
display(df_datetime_dim)
# Out:
#                   fk_Timestamp        Date      Time  Hour  Day_of_Week  \
# 0    2024-12-01 08:19:12+00:00  2024-12-01  08:19:12     8            6
# 1    2024-12-01 08:51:40+00:00  2024-12-01  08:51:40     8            6
# 2    2024-12-01 12:03:31+00:00  2024-12-01  12:03:31    12            6
# 3    2024-12-01 12:27:32+00:00  2024-12-01  12:27:32    12            6
# 4    2024-12-01 13:10:38+00:00  2024-12-01  13:10:38    13            6
# ...                        ...         ...       ...   ...          ...
# 1013 2025-01-23 17:00:55+00:00  2025-01-23  17:00:55    17            3
# 1014 2025-01-23 17:06:07+00:00  2025-01-23  17:06:07    17            3
# 1015 2025-01-23 17:12:57+00:00  2025-01-23  17:12:57    17            3
# 1016 2025-01-23 17:39:04+00:00  2025-01-23  17:39:04    17            3
# 1017 2025-01-23 17:58:25+00:00  2025-01-23  17:58:25    17            3
#
#      Day_of_Week_String
# 0                   Sun
# 1                   Sun
# 2                   Sun
# 3                   Sun
# 4                   Sun
# ...                 ...
# 1013                Thu
# 1014                Thu
# 1015                Thu
# 1016                Thu
# 1017                Thu
#
# [1018 rows x 6 columns]

# %% [markdown]
# ## Create an Address Dim

# %%
# Extract unique 'From' addresses and display names
from_addresses = df_emails_imap[['From_Display_Name', 'From_Addr']].drop_duplicates()
from_addresses.columns = ['Display_Name', 'fk_Email_Addr']

# Extract unique 'To' addresses and display names
to_addresses = df_emails_imap[['To_Display_Name', 'To_Addr']].drop_duplicates()
to_addresses.columns = ['Display_Name', 'fk_Email_Addr']

# Combine the two DataFrames
email_addresses_dim = pd.concat([from_addresses, to_addresses]).drop_duplicates().reset_index(drop=True)

# Reorder columns to make 'fk_Email_Addr' the first column
cols = ['fk_Email_Addr'] + [col for col in email_addresses_dim.columns if col != 'fk_Email_Addr']
email_addresses_dim = email_addresses_dim[cols]

# Display the email addresses dimension
display(email_addresses_dim)
# Out:
#                                          fk_Email_Addr  \
# 0                                do-not-reply@imdb.com
# 1                notifications@updates.bandsintown.com
# 2                english-personalized-digest@quora.com
# 3    USPSInformeddelivery@email.informeddelivery.us...
# 4                               extracare@your.cvs.com
# ..                                                 ...
# 476                               Mike@MikeCancell.com
# 477                             mike.cancell@gmail.com
# 478                             mike.cancell@gmail.com
# 479                             Mike.Cancell@gmail.com
# 480                             Mike.Cancell@gmail.com
#
#                          Display_Name
# 0                            IMDb.com
# 1                         Bandsintown
# 2                        Quora Digest
# 3              USPS Informed Delivery
# 4    =?UTF-8?B?Q1ZTIEV4dHJhQ2FyZQ==?=
# ..                                ...
# 476              Mike@MikeCancell.com
# 477        =?UTF-8?Q?Mike=20Cancell?=
# 478                     Cancell, Mike
# 479                 'Michael Cancell'
# 480                Michael P. Cancell
#
# [481 rows x 2 columns]

# %% [markdown]
# ## Add a Col for the Main Domain from the Addr

# %%
# Function to extract the main domain from an email address
def extract_main_domain(email):
    domain = email.split('@')[-1]
    main_domain = '.'.join(domain.split('.')[-2:])
    return main_domain

# Apply the function to the 'fk_Email_Addr' column
email_addresses_dim['Main_Domain'] = email_addresses_dim['fk_Email_Addr'].apply(extract_main_domain)

# Display the updated DataFrame
display(email_addresses_dim)
# Out:
#                                          fk_Email_Addr  \
# 0                                do-not-reply@imdb.com
# 1                notifications@updates.bandsintown.com
# 2                english-personalized-digest@quora.com
# 3    USPSInformeddelivery@email.informeddelivery.us...
# 4                               extracare@your.cvs.com
# ..                                                 ...
# 476                               Mike@MikeCancell.com
# 477                             mike.cancell@gmail.com
# 478                             mike.cancell@gmail.com
# 479                             Mike.Cancell@gmail.com
# 480                             Mike.Cancell@gmail.com
#
#                          Display_Name      Main_Domain
# 0                            IMDb.com         imdb.com
# 1                         Bandsintown  bandsintown.com
# 2                        Quora Digest        quora.com
# 3              USPS Informed Delivery         usps.com
# 4    =?UTF-8?B?Q1ZTIEV4dHJhQ2FyZQ==?=          cvs.com
# ..                                ...              ...
# 476              Mike@MikeCancell.com  MikeCancell.com
# 477        =?UTF-8?Q?Mike=20Cancell?=        gmail.com
# 478                     Cancell, Mike        gmail.com
# 479                 'Michael Cancell'        gmail.com
# 480                Michael P. Cancell        gmail.com
#
# [481 rows x 3 columns]

# %% [markdown]
# ## Now from the Main Domain, Let's try to Get the Company Name from the Internet

# %% [markdown]
# ### This can take a while!

# %%
# %pip install python-whois requests beautifulsoup4

import whois as python_whois
import requests
from bs4 import BeautifulSoup

# Function to get company name from main domain
def get_company_name(main_domain):
    try:
        # Get whois information
        domain_info = python_whois.whois(main_domain)
        if domain_info and domain_info.get('org'):
            return domain_info['org']
        
        # If whois information is not available, fetch the website content
        response = requests.get(f'http://{main_domain}')
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            # Try to find the company name in the title or meta tags
            title = soup.find('title')
            if title:
                return title.text.strip()
            meta = soup.find('meta', attrs={'name': 'description'})
            if meta and meta.get('content'):
                return meta['content'].strip()
    except Exception as e:
        print(f"Error resolving company name for domain {main_domain}: {e}")
    return 'Unknown'

# Apply the function to the 'Main_Domain' column
email_addresses_dim['Company_Name'] = email_addresses_dim['Main_Domain'].apply(get_company_name)

# Display the updated DataFrame
display(email_addresses_dim)
# Out:
# Requirement already satisfied: python-whois in c:\users\mike\appdata\local\programs\python\python313\lib\site-packages (0.9.5)
# Requirement already satisfied: requests in c:\users\mike\appdata\local\programs\python\python313\lib\site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\mike\appdata\local\programs\python\python313\lib\site-packages (4.12.3)
# Requirement already satisfied: python-dateutil in c:\users\mike\appdata\local\programs\python\python313\lib\site-packages (from python-whois) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mike\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mike\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mike\appdata\local\programs\python\python313\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mike\appdata\local\programs\python\python313\lib\site-packages (from requests) (2024.12.14)
# Requirement already satisfied: soupsieve>1.2 in c:\users\mike\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: six>=1.5 in c:\users\mike\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil->python-whois) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Error resolving company name for domain greenhouse-mail.io: HTTPConnectionPool(host='greenhouse-mail.io', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x000002D6B0333680>: Failed to resolve 'greenhouse-mail.io' ([Errno 11001] getaddrinfo failed)"))

# %%
# Merge the email addresses dimension with the main DataFrame on 'From_Addr' and 'To_Addr'
fact_table = df_emails_imap.merge(email_addresses_dim, left_on='From_Addr', right_on='fk_Email_Addr', how='left')
fact_table = fact_table.merge(email_addresses_dim, left_on='To_Addr', right_on='fk_Email_Addr', how='left', suffixes=('_From', '_To'))

# Merge the datetime dimension with the main DataFrame on 'Timestamp'
fact_table = fact_table.merge(df_datetime_dim, left_on='Timestamp', right_on='fk_Timestamp', how='left')

# Select relevant columns for the fact table
fact_table = fact_table[['Timestamp', 'Subject', 'Message-ID', 'From_Addr', 'To_Addr', 'Body_Text', 'Email_Category']]

# Display the fact table
display(fact_table)
# Out:
#                       Timestamp                           Subject  \
# 0     2024-12-01 08:19:12+00:00  See what's streaming in December
# 1     2024-12-01 08:19:12+00:00  See what's streaming in December
# 2     2024-12-01 08:19:12+00:00  See what's streaming in December
# 3     2024-12-01 08:19:12+00:00  See what's streaming in December
# 4     2024-12-01 08:19:12+00:00  See what's streaming in December
# ...                         ...                               ...
# 22547 2025-01-23 17:58:25+00:00        Thanks for applying to ECP
# 22548 2025-01-23 17:58:25+00:00        Thanks for applying to ECP
# 22549 2025-01-23 17:58:25+00:00        Thanks for applying to ECP
# 22550 2025-01-23 17:58:25+00:00        Thanks for applying to ECP
# 22551 2025-01-23 17:58:25+00:00        Thanks for applying to ECP
#
#                                               Message-ID  \
# 0      <01000193814d60c2-fd528199-2ca9-40dc-8c71-c310...
# 1      <01000193814d60c2-fd528199-2ca9-40dc-8c71-c310...
# 2      <01000193814d60c2-fd528199-2ca9-40dc-8c71-c310...
# 3      <01000193814d60c2-fd528199-2ca9-40dc-8c71-c310...
# 4      <01000193814d60c2-fd528199-2ca9-40dc-8c71-c310...
# ...                                                  ...
# 22547  <df0066ff-af68-4061-b474-f0610f4d1716@workable...
# 22548  <df0066ff-af68-4061-b474-f0610f4d1716@workable...
# 22549  <df0066ff-af68-4061-b474-f0610f4d1716@workable...
# 22550  <df0066ff-af68-4061-b474-f0610f4d1716@workable...
# 22551  <df0066ff-af68-4061-b474-f0610f4d1716@workable...
#
#                                  From_Addr                 To_Addr  \
# 0                    do-not-reply@imdb.com  mike.cancell@gmail.com
# 1                    do-not-reply@imdb.com  mike.cancell@gmail.com
# 2                    do-not-reply@imdb.com  mike.cancell@gmail.com
# 3                    do-not-reply@imdb.com  mike.cancell@gmail.com
# 4                    do-not-reply@imdb.com  mike.cancell@gmail.com
# ...                                    ...                     ...
# 22547  noreply@candidates.workablemail.com  mike.cancell@gmail.com
# 22548  noreply@candidates.workablemail.com  mike.cancell@gmail.com
# 22549  noreply@candidates.workablemail.com  mike.cancell@gmail.com
# 22550  noreply@candidates.workablemail.com  mike.cancell@gmail.com
# 22551  noreply@candidates.workablemail.com  mike.cancell@gmail.com
#
#                                                Body_Text Email_Category
# 0      IMDb Streaming Guides\r\nCheck out our watch g...  Entertainment
# 1      IMDb Streaming Guides\r\nCheck out our watch g...  Entertainment
# 2      IMDb Streaming Guides\r\nCheck out our watch g...  Entertainment
# 3      IMDb Streaming Guides\r\nCheck out our watch g...  Entertainment
# 4      IMDb Streaming Guides\r\nCheck out our watch g...  Entertainment
# ...                                                  ...            ...
# 22547  ECP\r\n\r\n-----------------------------------...          Other
# 22548  ECP\r\n\r\n-----------------------------------...          Other
# 22549  ECP\r\n\r\n-----------------------------------...          Other
# 22550  ECP\r\n\r\n-----------------------------------...          Other
# 22551  ECP\r\n\r\n-----------------------------------...          Other
#
# [22552 rows x 7 columns]

# %%
# Get the initial count of rows in the fact table
initial_count = fact_table.shape[0]

# Drop duplicates from the fact table
fact_table.drop_duplicates(inplace=True)

# Get the final count of rows in the fact table
final_count = fact_table.shape[0]

# Calculate the number of dropped rows
dropped_count = initial_count - final_count

# Display the count of dropped rows
print(f"Number of dropped rows: {dropped_count}")

# Display the updated fact table
display(fact_table)
# Out:
# Number of dropped rows: 21516
#                       Timestamp  \
# 0     2024-12-01 08:19:12+00:00
# 11    2024-12-01 08:51:40+00:00
# 22    2024-12-01 12:03:31+00:00
# 33    2024-12-01 12:27:32+00:00
# 44    2024-12-01 13:10:38+00:00
# ...                         ...
# 22442 2025-01-23 17:00:55+00:00
# 22453 2025-01-23 17:06:07+00:00
# 22464 2025-01-23 17:12:57+00:00
# 22475 2025-01-23 17:39:04+00:00
# 22486 2025-01-23 17:58:25+00:00
#
#                                                  Subject  \
# 0                       See what's streaming in December
# 11     Coming soon to State Theatre New Jersey: Cirqu...
# 22                  =?utf-8?q?Will_Obama_go_to_jail=3F?=
# 33      Your Daily Digest for Sun, 12/1 is ready to view
# 44     Your Weekly Ad + Holiday Savings to Deck the H...
# ...                                                  ...
# 22442              New Year, New Opportunities with NDR!
# 22453                       More opportunities available
# 22464     Thank you for your interest in Quince, Michael
# 22475                    Update on your Alma Application
# 22486                         Thanks for applying to ECP
#
#                                               Message-ID  \
# 0      <01000193814d60c2-fd528199-2ca9-40dc-8c71-c310...
# 11               <msg-19742805299@email.bandsintown.com>
# 22     <LARkCC7mJXguO-fXuuzZcwMdZJYRZCZHc2nstcrUwcMNj...
# 33     <20241201122732.9884238d69c03837@email.informe...
# 44        <0.3.9.54A.1DB43F26A5DD630.0@omp.your.cvs.com>
# ...                                                  ...
# 22442  <44.B0.11346.7C572976@i-0781014fc37ad6864.mta1...
# 22453  <010001949420d725-a7c812c3-e1be-4b04-8651-bcd6...
# 22464  <20250123171257.e66f35b6b0e4ab8d@gh-mail.onequ...
# 22475  <20250123173904.2f49b196001b2525@gh-mail.hello...
# 22486  <df0066ff-af68-4061-b474-f0610f4d1716@workable...
#
#                                                From_Addr  \
# 0                                  do-not-reply@imdb.com
# 11                 notifications@updates.bandsintown.com
# 22                 english-personalized-digest@quora.com
# 33     USPSInformeddelivery@email.informeddelivery.us...
# 44                                extracare@your.cvs.com
# ...                                                  ...
# 22442               nationaldebtrelief@nurture.icims.com
# 22453                            hello@thehustlewing.com
# 22464                             no-reply@onequince.com
# 22475                             no-reply@helloalma.com
# 22486                noreply@candidates.workablemail.com
#
#                       To_Addr  \
# 0      mike.cancell@gmail.com
# 11     mike.cancell@gmail.com
# 22     mike.cancell@gmail.com
# 33     mike.cancell@gmail.com
# 44       mike@mikecancell.com
# ...                       ...
# 22442  mike.cancell@gmail.com
# 22453  mike.cancell@gmail.com
# 22464  mike.cancell@gmail.com
# 22475  mike.cancell@gmail.com
# 22486  mike.cancell@gmail.com
#
#                                                Body_Text Email_Category
# 0      IMDb Streaming Guides\r\nCheck out our watch g...  Entertainment
# 11     Just Announced Cirque Musica, New Jersey Symph...          Music
# 22     Top stories for Mike\r\n\r\n-----\r\n\r\nQuest...     Newsletter
# 33     Content-Type: text/plain; charset=UTF-8\r\nCon...       Shipping
# 44     CVS\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...       Shipping
# ...                                                  ...            ...
# 22442  ![image] (\r\n \r\nCheck out our open roles an...          Other
# 22453  Hey Michael,\r\nI saw that you applied to an o...          Other
# 22464  Hi Michael,\r\n\r\nThank you for your interest...  Job Rejection
# 22475  Hi Michael,\r\n\r\nThank you very much for tak...  Job Rejection
# 22486  ECP\r\n\r\n-----------------------------------...          Other
#
# [1036 rows x 7 columns]
