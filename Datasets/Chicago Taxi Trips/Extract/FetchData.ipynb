# %% [markdown]
# # Extracting and Ingresting Data

# %% [markdown]
# ## Extract JSON Data from Web

# %% [markdown]
# ### Reading Data into local JSON storage

# %% [markdown]
# #### Define Func to Fetch and Store the JSON locally

# %%
import os
import requests
import json
import zipfile
import sys
sys.path.append('../../../Common')
from func_Fetch_Data import fetch_store_zip_json_data

def fetch_store_zip_json_data(limit, offset, url, chunk_size, storage_dir, storage_file, where_clause, compress=False, mode='w'):
    """
    Fetches data from a specified URL in chunks and stores it in a JSON file.
    Parameters:
    limit (int): The maximum number of records to fetch.
    offset (int): The starting point for fetching records.
    url (str): The URL to fetch data from, with placeholders for chunk_size, offset, and where_clause.
    chunk_size (int): The number of records to fetch in each request.
    storage_dir (str): The directory where the JSON file will be stored.
    storage_file (str): The name of the JSON file to store the fetched data.
    where_clause (str): The where clause to filter records, formatted as a string.
    compress (bool): Whether to compress the JSON file into a zip file.
    mode (str): The mode to open the JSON file, either 'w' for write or 'a' for append.
    Returns:
    None
    """
    final_url = url.format(chunk_size, offset, where_clause)
    print(f"Final URL: {final_url}")
    all_data = []

    while offset < limit:
        response = requests.get(url.format(chunk_size, offset, where_clause))
        data = response.json()
        if not data:
            print("No more data to fetch.")
            break
        all_data.extend(data)
        print(f"Fetched {len(data) + offset} out of {limit} requested records, offset is now {offset}")
        offset += chunk_size
        
    # Create the directory if it does not exist
    os.makedirs(storage_dir, exist_ok=True)
    print(f"Storage directory '{storage_dir}' is ready.")

    # Write or append the data to a JSON file
    json_path = os.path.join(storage_dir, storage_file)
    if mode == 'a' and os.path.exists(json_path):
        with open(json_path, mode='r') as file:
            existing_data = json.load(file)
        all_data = existing_data + all_data
        print(f"Existing data loaded from '{json_path}'.")

    # If no new data was fetched, ensure existing data is preserved
    if not all_data and mode == 'a' and os.path.exists(json_path):
        with open(json_path, mode='r') as file:
            all_data = json.load(file)
        mode = 'w'  # Change mode to 'w' to overwrite with existing data
        print("No new data fetched, preserving existing data.")

    if all_data:  # Only write to file if there is data to write
        with open(json_path, mode=mode) as file:
            json.dump(all_data, file, indent=4)
        print(f"Data written to '{json_path}'.")

    # Compress the JSON file if compress is True
    if compress:
        zip_path = json_path + '.zip'
        with zipfile.ZipFile(zip_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
            zipf.write(json_path, os.path.basename(json_path))
        os.remove(json_path)
        print(f"Data compressed to '{zip_path}'.")

    print("Data fetching and storing process completed.")

# %% [markdown]
# #### Perform an Initial Load of Data

# %%
from datetime import datetime
from dateutil.relativedelta import relativedelta

from_date_str = (datetime.now() - relativedelta(months=3)).isoformat()
where_clause = f"trip_start_timestamp>='{from_date_str}'"

fetch_store_zip_json_data(
    limit=200000,
    offset=0,
    url="https://data.cityofchicago.org/resource/ajtu-isnz.json?$limit={}&$offset={}&$where={}",
    chunk_size=1000,
    storage_dir='C:/Users/mike/Data/Public',
    storage_file='Chi_Taxi_Trips.json',
    where_clause=where_clause,
    compress=False,
    mode='w'
)
# Out:
# Final URL: https://data.cityofchicago.org/resource/ajtu-isnz.json?$limit=1000&$offset=0&$where=trip_start_timestamp>='2024-10-17T15:58:56.645269'
# Fetched 1000 out of 200000 requested records, offset is now 0
# Fetched 2000 out of 200000 requested records, offset is now 1000
# Fetched 3000 out of 200000 requested records, offset is now 2000
# Fetched 4000 out of 200000 requested records, offset is now 3000
# Fetched 5000 out of 200000 requested records, offset is now 4000
# Fetched 6000 out of 200000 requested records, offset is now 5000
# Fetched 7000 out of 200000 requested records, offset is now 6000
# Fetched 8000 out of 200000 requested records, offset is now 7000
# Fetched 9000 out of 200000 requested records, offset is now 8000
# Fetched 10000 out of 200000 requested records, offset is now 9000
# Fetched 11000 out of 200000 requested records, offset is now 10000
# Fetched 12000 out of 200000 requested records, offset is now 11000
# Fetched 13000 out of 200000 requested records, offset is now 12000
# Fetched 14000 out of 200000 requested records, offset is now 13000
# Fetched 15000 out of 200000 requested records, offset is now 14000
# Fetched 16000 out of 200000 requested records, offset is now 15000
# Fetched 17000 out of 200000 requested records, offset is now 16000
# Fetched 18000 out of 200000 requested records, offset is now 17000
# Fetched 19000 out of 200000 requested records, offset is now 18000
# Fetched 20000 out of 200000 requested records, offset is now 19000
# Fetched 21000 out of 200000 requested records, offset is now 20000
# Fetched 22000 out of 200000 requested records, offset is now 21000
# Fetched 23000 out of 200000 requested records, offset is now 22000
# Fetched 24000 out of 200000 requested records, offset is now 23000
# Fetched 25000 out of 200000 requested records, offset is now 24000
# Fetched 26000 out of 200000 requested records, offset is now 25000
# Fetched 27000 out of 200000 requested records, offset is now 26000
# Fetched 28000 out of 200000 requested records, offset is now 27000
# Fetched 29000 out of 200000 requested records, offset is now 28000
# Fetched 30000 out of 200000 requested records, offset is now 29000
# Fetched 31000 out of 200000 requested records, offset is now 30000
# Fetched 32000 out of 200000 requested records, offset is now 31000
# Fetched 33000 out of 200000 requested records, offset is now 32000
# Fetched 34000 out of 200000 requested records, offset is now 33000
# Fetched 35000 out of 200000 requested records, offset is now 34000
# Fetched 36000 out of 200000 requested records, offset is now 35000
# Fetched 37000 out of 200000 requested records, offset is now 36000
# Fetched 38000 out of 200000 requested records, offset is now 37000
# Fetched 39000 out of 200000 requested records, offset is now 38000
# Fetched 40000 out of 200000 requested records, offset is now 39000
# Fetched 41000 out of 200000 requested records, offset is now 40000
# Fetched 42000 out of 200000 requested records, offset is now 41000
# Fetched 43000 out of 200000 requested records, offset is now 42000
# Fetched 44000 out of 200000 requested records, offset is now 43000
# Fetched 45000 out of 200000 requested records, offset is now 44000
# Fetched 46000 out of 200000 requested records, offset is now 45000
# Fetched 47000 out of 200000 requested records, offset is now 46000
# Fetched 48000 out of 200000 requested records, offset is now 47000
# Fetched 49000 out of 200000 requested records, offset is now 48000
# Fetched 50000 out of 200000 requested records, offset is now 49000
# Fetched 51000 out of 200000 requested records, offset is now 50000
# Fetched 52000 out of 200000 requested records, offset is now 51000
# Fetched 53000 out of 200000 requested records, offset is now 52000
# Fetched 54000 out of 200000 requested records, offset is now 53000
# Fetched 55000 out of 200000 requested records, offset is now 54000
# Fetched 56000 out of 200000 requested records, offset is now 55000
# Fetched 57000 out of 200000 requested records, offset is now 56000
# Fetched 58000 out of 200000 requested records, offset is now 57000
# Fetched 59000 out of 200000 requested records, offset is now 58000
# Fetched 60000 out of 200000 requested records, offset is now 59000
# Fetched 61000 out of 200000 requested records, offset is now 60000
# Fetched 62000 out of 200000 requested records, offset is now 61000
# Fetched 63000 out of 200000 requested records, offset is now 62000
# Fetched 64000 out of 200000 requested records, offset is now 63000
# Fetched 65000 out of 200000 requested records, offset is now 64000
# Fetched 66000 out of 200000 requested records, offset is now 65000
# Fetched 67000 out of 200000 requested records, offset is now 66000
# Fetched 68000 out of 200000 requested records, offset is now 67000
# Fetched 69000 out of 200000 requested records, offset is now 68000
# Fetched 70000 out of 200000 requested records, offset is now 69000
# Fetched 71000 out of 200000 requested records, offset is now 70000
# Fetched 72000 out of 200000 requested records, offset is now 71000
# Fetched 73000 out of 200000 requested records, offset is now 72000
# Fetched 74000 out of 200000 requested records, offset is now 73000
# Fetched 75000 out of 200000 requested records, offset is now 74000
# Fetched 76000 out of 200000 requested records, offset is now 75000
# Fetched 77000 out of 200000 requested records, offset is now 76000
# Fetched 78000 out of 200000 requested records, offset is now 77000
# Fetched 79000 out of 200000 requested records, offset is now 78000
# Fetched 80000 out of 200000 requested records, offset is now 79000
# Fetched 81000 out of 200000 requested records, offset is now 80000
# Fetched 82000 out of 200000 requested records, offset is now 81000
# Fetched 83000 out of 200000 requested records, offset is now 82000
# Fetched 84000 out of 200000 requested records, offset is now 83000
# Fetched 85000 out of 200000 requested records, offset is now 84000
# Fetched 86000 out of 200000 requested records, offset is now 85000
# Fetched 87000 out of 200000 requested records, offset is now 86000
# Fetched 88000 out of 200000 requested records, offset is now 87000
# Fetched 89000 out of 200000 requested records, offset is now 88000
# Fetched 90000 out of 200000 requested records, offset is now 89000
# Fetched 91000 out of 200000 requested records, offset is now 90000
# Fetched 92000 out of 200000 requested records, offset is now 91000
# Fetched 93000 out of 200000 requested records, offset is now 92000
# Fetched 94000 out of 200000 requested records, offset is now 93000
# Fetched 95000 out of 200000 requested records, offset is now 94000
# Fetched 96000 out of 200000 requested records, offset is now 95000
# Fetched 97000 out of 200000 requested records, offset is now 96000
# Fetched 98000 out of 200000 requested records, offset is now 97000
# Fetched 99000 out of 200000 requested records, offset is now 98000
# Fetched 100000 out of 200000 requested records, offset is now 99000
# Fetched 101000 out of 200000 requested records, offset is now 100000
# Fetched 102000 out of 200000 requested records, offset is now 101000
# Fetched 103000 out of 200000 requested records, offset is now 102000
# Fetched 104000 out of 200000 requested records, offset is now 103000
# Fetched 105000 out of 200000 requested records, offset is now 104000
# Fetched 106000 out of 200000 requested records, offset is now 105000
# Fetched 107000 out of 200000 requested records, offset is now 106000
# Fetched 108000 out of 200000 requested records, offset is now 107000
# Fetched 109000 out of 200000 requested records, offset is now 108000
# Fetched 110000 out of 200000 requested records, offset is now 109000
# Fetched 111000 out of 200000 requested records, offset is now 110000
# Fetched 112000 out of 200000 requested records, offset is now 111000
# Fetched 113000 out of 200000 requested records, offset is now 112000
# Fetched 114000 out of 200000 requested records, offset is now 113000
# Fetched 115000 out of 200000 requested records, offset is now 114000
# Fetched 116000 out of 200000 requested records, offset is now 115000
# Fetched 117000 out of 200000 requested records, offset is now 116000
# Fetched 118000 out of 200000 requested records, offset is now 117000
# Fetched 119000 out of 200000 requested records, offset is now 118000
# Fetched 120000 out of 200000 requested records, offset is now 119000
# Fetched 121000 out of 200000 requested records, offset is now 120000
# Fetched 122000 out of 200000 requested records, offset is now 121000
# Fetched 123000 out of 200000 requested records, offset is now 122000
# Fetched 124000 out of 200000 requested records, offset is now 123000
# Fetched 125000 out of 200000 requested records, offset is now 124000
# Fetched 126000 out of 200000 requested records, offset is now 125000
# Fetched 127000 out of 200000 requested records, offset is now 126000
# Fetched 128000 out of 200000 requested records, offset is now 127000
# Fetched 129000 out of 200000 requested records, offset is now 128000
# Fetched 130000 out of 200000 requested records, offset is now 129000
# Fetched 131000 out of 200000 requested records, offset is now 130000
# Fetched 132000 out of 200000 requested records, offset is now 131000
# Fetched 133000 out of 200000 requested records, offset is now 132000
# Fetched 134000 out of 200000 requested records, offset is now 133000
# Fetched 135000 out of 200000 requested records, offset is now 134000
# Fetched 136000 out of 200000 requested records, offset is now 135000
# Fetched 137000 out of 200000 requested records, offset is now 136000
# Fetched 138000 out of 200000 requested records, offset is now 137000
# Fetched 139000 out of 200000 requested records, offset is now 138000
# Fetched 140000 out of 200000 requested records, offset is now 139000
# Fetched 141000 out of 200000 requested records, offset is now 140000
# Fetched 142000 out of 200000 requested records, offset is now 141000
# Fetched 143000 out of 200000 requested records, offset is now 142000
# Fetched 144000 out of 200000 requested records, offset is now 143000
# Fetched 145000 out of 200000 requested records, offset is now 144000
# Fetched 146000 out of 200000 requested records, offset is now 145000
# Fetched 147000 out of 200000 requested records, offset is now 146000
# Fetched 148000 out of 200000 requested records, offset is now 147000
# Fetched 149000 out of 200000 requested records, offset is now 148000
# Fetched 150000 out of 200000 requested records, offset is now 149000
# Fetched 151000 out of 200000 requested records, offset is now 150000
# Fetched 152000 out of 200000 requested records, offset is now 151000
# Fetched 153000 out of 200000 requested records, offset is now 152000
# Fetched 154000 out of 200000 requested records, offset is now 153000
# Fetched 155000 out of 200000 requested records, offset is now 154000
# Fetched 156000 out of 200000 requested records, offset is now 155000
# Fetched 157000 out of 200000 requested records, offset is now 156000
# Fetched 158000 out of 200000 requested records, offset is now 157000
# Fetched 159000 out of 200000 requested records, offset is now 158000
# Fetched 160000 out of 200000 requested records, offset is now 159000
# Fetched 161000 out of 200000 requested records, offset is now 160000
# Fetched 162000 out of 200000 requested records, offset is now 161000
# Fetched 163000 out of 200000 requested records, offset is now 162000
# Fetched 164000 out of 200000 requested records, offset is now 163000
# Fetched 165000 out of 200000 requested records, offset is now 164000
# Fetched 166000 out of 200000 requested records, offset is now 165000
# Fetched 167000 out of 200000 requested records, offset is now 166000
# Fetched 168000 out of 200000 requested records, offset is now 167000
# Fetched 169000 out of 200000 requested records, offset is now 168000
# Fetched 170000 out of 200000 requested records, offset is now 169000
# Fetched 171000 out of 200000 requested records, offset is now 170000
# Fetched 172000 out of 200000 requested records, offset is now 171000
# Fetched 173000 out of 200000 requested records, offset is now 172000
# Fetched 174000 out of 200000 requested records, offset is now 173000
# Fetched 175000 out of 200000 requested records, offset is now 174000
# Fetched 176000 out of 200000 requested records, offset is now 175000
# Fetched 177000 out of 200000 requested records, offset is now 176000
# Fetched 178000 out of 200000 requested records, offset is now 177000
# Fetched 179000 out of 200000 requested records, offset is now 178000
# Fetched 180000 out of 200000 requested records, offset is now 179000
# Fetched 181000 out of 200000 requested records, offset is now 180000
# Fetched 182000 out of 200000 requested records, offset is now 181000
# Fetched 183000 out of 200000 requested records, offset is now 182000
# Fetched 184000 out of 200000 requested records, offset is now 183000
# Fetched 185000 out of 200000 requested records, offset is now 184000
# Fetched 186000 out of 200000 requested records, offset is now 185000
# Fetched 187000 out of 200000 requested records, offset is now 186000
# Fetched 188000 out of 200000 requested records, offset is now 187000
# Fetched 189000 out of 200000 requested records, offset is now 188000
# Fetched 190000 out of 200000 requested records, offset is now 189000
# Fetched 191000 out of 200000 requested records, offset is now 190000
# Fetched 192000 out of 200000 requested records, offset is now 191000
# Fetched 193000 out of 200000 requested records, offset is now 192000
# Fetched 194000 out of 200000 requested records, offset is now 193000
# Fetched 195000 out of 200000 requested records, offset is now 194000
# Fetched 196000 out of 200000 requested records, offset is now 195000
# Fetched 197000 out of 200000 requested records, offset is now 196000
# Fetched 198000 out of 200000 requested records, offset is now 197000
# Fetched 199000 out of 200000 requested records, offset is now 198000
# Fetched 200000 out of 200000 requested records, offset is now 199000
# Storage directory 'C:/Users/mike/Data/Public' is ready.
# Data written to 'C:/Users/mike/Data/Public\Chi_Taxi_Trips.json'.
# Data fetching and storing process completed.

# %% [markdown]
# #### Define Func to Retrive the Latest Timestamp from the JSON to be used for incremental loading

# %%
import json
from datetime import datetime

def get_latest_timestamp_from_json(json_file_path):
    """
    Extracts the latest timestamp from the JSON file and returns it as a string in ISO format.
    
    Parameters:
    json_file_path (str): The path to the JSON file.
    
    Returns:
    str: The latest timestamp in ISO format.
    """
    timestamps = []
    with open(json_file_path, 'r') as file:
        try:
            data = json.load(file)
            for record in data:
                if 'trip_start_timestamp' in record:
                    timestamps.append(datetime.fromisoformat(record['trip_start_timestamp']))
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON: {e}")
    
    if not timestamps:
        raise ValueError("No valid timestamps found in the JSON file.")
    
    # Get the latest timestamp
    latest_timestamp = max(timestamps)
    
    return latest_timestamp.isoformat()

# Example usage
latest_timestamp = get_latest_timestamp_from_json('C:/Users/mike/Data/Public/Chi_Taxi_Trips.json')
print(latest_timestamp)
# Out:
# 2025-01-01T00:00:00

# %% [markdown]
# ####  Call the Fetch Function with the 'a'ppend option to load data incrementally
# This is the function that you would use in a scheduled Orchestration Workflow Tools, etc. Airflow, NiFi, or even Windows Scheduler

# %%
# Format the where clause to filter records based on the latest timestamp
where_clause = f"trip_start_timestamp>'{latest_timestamp}'"

fetch_store_zip_json_data(
    limit=1000,
    offset=0,
    url="https://data.cityofchicago.org/resource/ajtu-isnz.json?$limit={}&$offset={}&$where={}",
    chunk_size=1000,
    storage_dir='C:/Users/mike/Data/Public/Data',
    storage_file='Chi_Taxi_Trips.json',
    where_clause=where_clause,
    mode='a'
)
# Out:
# Final URL: https://data.cityofchicago.org/resource/ajtu-isnz.json?$limit=1000&$offset=0&$where=trip_start_timestamp>'2025-01-01T00:00:00'
# No more data to fetch.
# Storage directory 'C:/Users/mike/Data/Public/Data' is ready.
# Existing data loaded from 'C:/Users/mike/Data/Public/Data\Chi_Taxi_Trips.json'.
# Data written to 'C:/Users/mike/Data/Public/Data\Chi_Taxi_Trips.json'.
# Data fetching and storing process completed.
